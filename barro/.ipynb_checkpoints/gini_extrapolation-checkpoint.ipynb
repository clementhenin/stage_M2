# %%
# %matplotlib inline

# %%
from scipy.integrate import simps, trapz, cumtrapz
import pandas as pd
import numpy as np
import pylab as plt

# %%
data = pd.read_csv("../data_source/income_GDP_data.csv")
data.set_index(['year', 'code'], inplace=True)
numerical_variables = data.keys().tolist()
origins = np.array([item.split('_')[-1] for item in numerical_variables])
sources = set(origins)
origins = {source: np.array(numerical_variables)[origins==source] for source in sources}

# %%
test = data[origins['WID']].dropna(how="all").loc[2010].loc['JPN']
test
# Out:
# D1_WID                           41.57
# V1_WID                           27.02
# P1_WID                           10.44
# top_0.5_income_share_WID          7.17
# Pr1_WID                           3.15
# top_0.05_income_share_WID         2.23
# top_0.01_income_share_WID         1.03
# national_income_WID          390223.40
# Name: JPN, dtype: float64

# %%
share_dict = {"D1_WID": 0.1, "V1_WID": 0.05, "P1_WID": 0.01, "top_0.5_income_share_WID": 0.005, 
              "Pr1_WID": 0.001, "top_0.05_income_share_WID": 0.0005, "top_0.01_income_share_WID": 0.0001}

# %%
lorentz = pd.DataFrame({"x-%_poorest": (1 - np.array(share_dict.values())), 
                        "share": [100 - test[var_name] for var_name in share_dict.keys()]})
lorentz.loc[len(lorentz) + 1] = {"share": 0, "x-%_poorest": 0}
lorentz.loc[len(lorentz) + 1] = {"share": 100, "x-%_poorest": 1}
lorentz = lorentz.sort("x-%_poorest")
lorentz
# Out:
#     share  x-%_poorest
# 8    0.00       0.0000
# 4   58.43       0.9000
# 5   72.98       0.9500
# 0   89.56       0.9900
# 3   92.83       0.9950
# 2   96.85       0.9990
# 1   97.77       0.9995
# 6   98.97       0.9999
# 9  100.00       1.0000

# %%
plt.plot(lorentz["x-%_poorest"].values, lorentz["share"].values / 100., 'o')

# %%
G = 1 - 2 * trapz(lorentz["share"].values / 100., lorentz["x-%_poorest"].values)
print("G = ", G)
# Out:
# ('G = ', 0.32474327000000003)

# %% [markdown]
# # Computation of the Gini coefficient from WID

# %%
data['gini_trapz'] = float('nan')
data['gini_simps'] = float('nan')
for row in data[share_dict.keys()].dropna(how="all").iterrows():
    actual_share_list = list(set(row[1].keys().values) & set(share_dict.keys()))
    actual_share_dict = dict((k, share_dict[k]) for k in actual_share_list)
    lorentz = pd.DataFrame({"x-%_poorest": (1 - np.array(actual_share_dict.values())), 
                        "share": [100 - row[1][var_name] for var_name in actual_share_dict.keys()]})
    lorentz.loc[len(lorentz) + 1] = {"share": 0, "x-%_poorest": 0}
    lorentz.loc[len(lorentz) + 1] = {"share": 100, "x-%_poorest": 1}
    lorentz = lorentz.sort("x-%_poorest")
    G_trapz = 1 - 2 * trapz(lorentz["share"].values / 100., lorentz["x-%_poorest"].values)
    G_simps = 1 - 2 * simps(lorentz["share"].values / 100., lorentz["x-%_poorest"].values)
    # data["gini_extra"][row[0][0]][row[0][1]] = G
    data.set_value((row[0][0], row[0][1]), 'gini_trapz', G_trapz)
    data.set_value((row[0][0], row[0][1]), 'gini_simps', G_simps)

# %%
row[1].keys()
# Out:
# Index([u'P1_WID', u'top_0.05_income_share_WID', u'Pr1_WID', u'top_0.5_income_share_WID', u'D1_WID', u'V1_WID', u'top_0.01_income_share_WID'], dtype='object')

# %%
data.query("code == 'JPN'")
# Out:
#            gini_DS  Q4_DS  Q3_DS  Q2_DS  Q1_DS  D1_WB  D9_WB  QU1_WB  QU2_WB  \
# year code
# 1886 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 1887 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 1888 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 1889 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 1890 JPN      31.1    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 1891 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 1892 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 1893 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 1894 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 1895 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 1896 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 1897 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 1898 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 1899 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 1900 JPN      41.7    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 1901 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 1902 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 1903 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 1904 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 1905 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 1906 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 1907 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 1908 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 1909 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 1910 JPN      42.0    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 1911 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 1912 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 1913 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 1914 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 1915 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# ...            ...    ...    ...    ...    ...    ...    ...     ...     ...
# 1985 JPN      35.9    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 1986 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 1987 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 1988 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 1989 JPN      37.6    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 1990 JPN      35.0    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 1991 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 1992 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 1993 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 1994 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 1995 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 1996 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 1997 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 1998 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 1999 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 2000 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 2001 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 2002 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 2003 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 2004 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 2005 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 2006 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 2007 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 2008 JPN       NaN    NaN    NaN    NaN    NaN  24.77   2.68   39.72   22.72
# 2009 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 2010 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 2011 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 2012 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 2013 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 2014 JPN       NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
#
#            QU3_WB     ...      top_0.5_income_share_WID  Pr1_WID  \
# year code             ...
# 1886 JPN      NaN     ...                           NaN      NaN
# 1887 JPN      NaN     ...                           NaN      NaN
# 1888 JPN      NaN     ...                           NaN      NaN
# 1889 JPN      NaN     ...                           NaN      NaN
# 1890 JPN      NaN     ...                           NaN      NaN
# 1891 JPN      NaN     ...                           NaN      NaN
# 1892 JPN      NaN     ...                           NaN      NaN
# 1893 JPN      NaN     ...                           NaN      NaN
# 1894 JPN      NaN     ...                           NaN      NaN
# 1895 JPN      NaN     ...                           NaN      NaN
# 1896 JPN      NaN     ...                           NaN      NaN
# 1897 JPN      NaN     ...                           NaN      NaN
# 1898 JPN      NaN     ...                           NaN      NaN
# 1899 JPN      NaN     ...                           NaN      NaN
# 1900 JPN      NaN     ...                           NaN      NaN
# 1901 JPN      NaN     ...                           NaN      NaN
# 1902 JPN      NaN     ...                           NaN      NaN
# 1903 JPN      NaN     ...                           NaN      NaN
# 1904 JPN      NaN     ...                           NaN      NaN
# 1905 JPN      NaN     ...                           NaN      NaN
# 1906 JPN      NaN     ...                           NaN      NaN
# 1907 JPN      NaN     ...                           NaN      NaN
# 1908 JPN      NaN     ...                           NaN      NaN
# 1909 JPN      NaN     ...                           NaN      NaN
# 1910 JPN      NaN     ...                           NaN      NaN
# 1911 JPN      NaN     ...                           NaN      NaN
# 1912 JPN      NaN     ...                           NaN      NaN
# 1913 JPN      NaN     ...                           NaN      NaN
# 1914 JPN      NaN     ...                           NaN      NaN
# 1915 JPN      NaN     ...                           NaN      NaN
# ...           ...     ...                           ...      ...
# 1985 JPN      NaN     ...                          5.72     2.36
# 1986 JPN      NaN     ...                          6.12     2.66
# 1987 JPN      NaN     ...                          7.37     3.52
# 1988 JPN      NaN     ...                          7.60     3.73
# 1989 JPN      NaN     ...                          8.86     4.65
# 1990 JPN      NaN     ...                          9.90     5.44
# 1991 JPN      NaN     ...                          9.15     4.85
# 1992 JPN      NaN     ...                          5.85     2.65
# 1993 JPN      NaN     ...                          6.02     2.72
# 1994 JPN      NaN     ...                          5.91     2.69
# 1995 JPN      NaN     ...                          5.97     2.60
# 1996 JPN      NaN     ...                          6.16     2.73
# 1997 JPN      NaN     ...                          5.67     2.36
# 1998 JPN      NaN     ...                          5.67     2.30
# 1999 JPN      NaN     ...                          5.84     2.41
# 2000 JPN      NaN     ...                          6.09     2.55
# 2001 JPN      NaN     ...                          6.33     2.64
# 2002 JPN      NaN     ...                          6.38     2.62
# 2003 JPN      NaN     ...                          6.61     2.77
# 2004 JPN      NaN     ...                          7.17     3.15
# 2005 JPN      NaN     ...                          7.72     3.60
# 2006 JPN      NaN     ...                          7.95     3.80
# 2007 JPN      NaN     ...                          8.00     3.86
# 2008 JPN    17.32     ...                          7.56     3.47
# 2009 JPN      NaN     ...                          7.17     3.15
# 2010 JPN      NaN     ...                          7.17     3.15
# 2011 JPN      NaN     ...                           NaN      NaN
# 2012 JPN      NaN     ...                           NaN      NaN
# 2013 JPN      NaN     ...                           NaN      NaN
# 2014 JPN      NaN     ...                           NaN      NaN
#
#            top_0.05_income_share_WID  top_0.01_income_share_WID  \
# year code
# 1886 JPN                         NaN                        NaN
# 1887 JPN                         NaN                        NaN
# 1888 JPN                         NaN                        NaN
# 1889 JPN                         NaN                        NaN
# 1890 JPN                         NaN                        NaN
# 1891 JPN                         NaN                        NaN
# 1892 JPN                         NaN                        NaN
# 1893 JPN                         NaN                        NaN
# 1894 JPN                         NaN                        NaN
# 1895 JPN                         NaN                        NaN
# 1896 JPN                         NaN                        NaN
# 1897 JPN                         NaN                        NaN
# 1898 JPN                         NaN                        NaN
# 1899 JPN                         NaN                        NaN
# 1900 JPN                         NaN                        NaN
# 1901 JPN                         NaN                        NaN
# 1902 JPN                         NaN                        NaN
# 1903 JPN                         NaN                        NaN
# 1904 JPN                         NaN                        NaN
# 1905 JPN                         NaN                        NaN
# 1906 JPN                         NaN                        NaN
# 1907 JPN                         NaN                        NaN
# 1908 JPN                         NaN                        NaN
# 1909 JPN                         NaN                        NaN
# 1910 JPN                         NaN                        NaN
# 1911 JPN                         NaN                        NaN
# 1912 JPN                         NaN                        NaN
# 1913 JPN                         NaN                        NaN
# 1914 JPN                         NaN                        NaN
# 1915 JPN                         NaN                        NaN
# ...                              ...                        ...
# 1985 JPN                        1.60                       0.64
# 1986 JPN                        1.85                       0.79
# 1987 JPN                        2.56                       1.21
# 1988 JPN                        2.74                       1.34
# 1989 JPN                        3.51                       1.83
# 1990 JPN                        4.20                       2.29
# 1991 JPN                        3.68                       1.95
# 1992 JPN                        1.91                       0.90
# 1993 JPN                        1.96                       0.92
# 1994 JPN                        1.92                       0.88
# 1995 JPN                        1.84                       0.82
# 1996 JPN                        1.93                       0.86
# 1997 JPN                        1.62                       0.67
# 1998 JPN                        1.56                       0.63
# 1999 JPN                        1.66                       0.70
# 2000 JPN                        1.76                       0.74
# 2001 JPN                        1.82                       0.77
# 2002 JPN                        1.78                       0.74
# 2003 JPN                        1.91                       0.81
# 2004 JPN                        2.23                       1.00
# 2005 JPN                        2.65                       1.36
# 2006 JPN                        2.82                       1.46
# 2007 JPN                        2.84                       1.49
# 2008 JPN                        2.50                       1.24
# 2009 JPN                        2.24                       1.06
# 2010 JPN                        2.23                       1.03
# 2011 JPN                         NaN                        NaN
# 2012 JPN                         NaN                        NaN
# 2013 JPN                         NaN                        NaN
# 2014 JPN                         NaN                        NaN
#
#            national_income_WID     GDP_PWT    GDP_PC_PWT  gini_extra  \
# year code
# 1886 JPN                   NaN         NaN           NaN         NaN
# 1887 JPN                   NaN         NaN           NaN         NaN
# 1888 JPN                   NaN         NaN           NaN         NaN
# 1889 JPN                   NaN         NaN           NaN         NaN
# 1890 JPN                   NaN         NaN           NaN         NaN
# 1891 JPN                   NaN         NaN           NaN         NaN
# 1892 JPN                   NaN         NaN           NaN         NaN
# 1893 JPN                   NaN         NaN           NaN         NaN
# 1894 JPN                   NaN         NaN           NaN         NaN
# 1895 JPN                   NaN         NaN           NaN         NaN
# 1896 JPN                   NaN         NaN           NaN         NaN
# 1897 JPN                   NaN         NaN           NaN         NaN
# 1898 JPN                   NaN         NaN           NaN         NaN
# 1899 JPN                   NaN         NaN           NaN         NaN
# 1900 JPN                   NaN         NaN           NaN         NaN
# 1901 JPN                   NaN         NaN           NaN         NaN
# 1902 JPN                   NaN         NaN           NaN         NaN
# 1903 JPN                   NaN         NaN           NaN         NaN
# 1904 JPN                   NaN         NaN           NaN         NaN
# 1905 JPN                   NaN         NaN           NaN         NaN
# 1906 JPN                   NaN         NaN           NaN         NaN
# 1907 JPN                   NaN         NaN           NaN         NaN
# 1908 JPN                   NaN         NaN           NaN         NaN
# 1909 JPN                   NaN         NaN           NaN         NaN
# 1910 JPN                   NaN         NaN           NaN         NaN
# 1911 JPN                   NaN         NaN           NaN         NaN
# 1912 JPN                   NaN         NaN           NaN         NaN
# 1913 JPN                   NaN         NaN           NaN         NaN
# 1914 JPN                   NaN         NaN           NaN         NaN
# 1915 JPN                   NaN         NaN           NaN         NaN
# ...                        ...         ...           ...         ...
# 1985 JPN          281781.92971  2001858.00  16683.464240    0.241751
# 1986 JPN          294191.29383  2147283.75  17811.909442    0.250064
# 1987 JPN          307328.32824  2290983.00  18930.054944    0.271324
# 1988 JPN          330089.12816  2530001.75  20834.260958    0.278153
# 1989 JPN          351809.63899  2740167.50  22491.190477    0.291309
# 1990 JPN          379907.06466  2960112.00  24213.360584    0.301021
# 1991 JPN          402465.86765  3148703.75  25661.176286    0.289740
# 1992 JPN          406974.85621  3263143.25  26491.379290    0.244655
# 1993 JPN          406292.28508  3358434.25  27160.062839    0.250408
# 1994 JPN          406178.31760  3485106.75  28083.584001    0.255114
# 1995 JPN          409326.87156  3662938.50  29424.325694    0.262766
# 1996 JPN          420490.03413  3751830.50  30059.134886    0.268036
# 1997 JPN          429072.37893  3786093.25  30266.573677    0.266282
# 1998 JPN          416706.22489  3699630.00  29520.141920    0.272443
# 1999 JPN          412201.06236  3661668.50  29169.292400    0.280219
# 2000 JPN          415008.72978  3745734.50  29794.187590    0.289008
# 2001 JPN          407091.40000  3769029.00  29938.204257    0.303859
# 2002 JPN          402612.50000  3779920.50  29987.857994    0.313621
# 2003 JPN          403572.10000  3828725.75  30342.366932    0.320460
# 2004 JPN          409222.20000  3897615.75  30860.125368    0.330546
# 2005 JPN          412919.70000  3907396.75  30914.674715    0.333933
# 2006 JPN          416235.60000  3953508.75  31261.735233    0.337478
# 2007 JPN          422744.60000  4036816.75  31907.688755    0.339588
# 2008 JPN          407084.30000  3944303.75  31169.267620    0.332437
# 2009 JPN          375345.20000  3775170.75  29831.054034    0.322193
# 2010 JPN          390223.40000  3912030.75  30916.365487    0.324743
# 2011 JPN          384783.60000  3868434.75  30581.178842         NaN
# 2012 JPN          390170.80000         NaN           NaN         NaN
# 2013 JPN          395966.50000         NaN           NaN         NaN
# 2014 JPN                   NaN         NaN           NaN         NaN
#
#            gini_trapz  gini_simps
# year code
# 1886 JPN          NaN         NaN
# 1887 JPN          NaN         NaN
# 1888 JPN          NaN         NaN
# 1889 JPN          NaN         NaN
# 1890 JPN          NaN         NaN
# 1891 JPN          NaN         NaN
# 1892 JPN          NaN         NaN
# 1893 JPN          NaN         NaN
# 1894 JPN          NaN         NaN
# 1895 JPN          NaN         NaN
# 1896 JPN          NaN         NaN
# 1897 JPN          NaN         NaN
# 1898 JPN          NaN         NaN
# 1899 JPN          NaN         NaN
# 1900 JPN          NaN         NaN
# 1901 JPN          NaN         NaN
# 1902 JPN          NaN         NaN
# 1903 JPN          NaN         NaN
# 1904 JPN          NaN         NaN
# 1905 JPN          NaN         NaN
# 1906 JPN          NaN         NaN
# 1907 JPN          NaN         NaN
# 1908 JPN          NaN         NaN
# 1909 JPN          NaN         NaN
# 1910 JPN          NaN         NaN
# 1911 JPN          NaN         NaN
# 1912 JPN          NaN         NaN
# 1913 JPN          NaN         NaN
# 1914 JPN          NaN         NaN
# 1915 JPN          NaN         NaN
# ...               ...         ...
# 1985 JPN     0.241751    0.652712
# 1986 JPN     0.250064    0.667400
# 1987 JPN     0.271324    0.702099
# 1988 JPN     0.278153    0.721568
# 1989 JPN     0.291309    0.737177
# 1990 JPN     0.301021    0.741200
# 1991 JPN     0.289740    0.720200
# 1992 JPN     0.244655    0.659377
# 1993 JPN     0.250408    0.677500
# 1994 JPN     0.255114    0.696857
# 1995 JPN     0.262766    0.724085
# 1996 JPN     0.268036    0.740044
# 1997 JPN     0.266282    0.750198
# 1998 JPN     0.272443    0.770413
# 1999 JPN     0.280219    0.789581
# 2000 JPN     0.289008    0.813613
# 2001 JPN     0.303859    0.861276
# 2002 JPN     0.313621    0.895825
# 2003 JPN     0.320460    0.909143
# 2004 JPN     0.330546    0.925567
# 2005 JPN     0.333933    0.921602
# 2006 JPN     0.337478    0.922501
# 2007 JPN     0.339588    0.930824
# 2008 JPN     0.332437    0.917164
# 2009 JPN     0.322193    0.891794
# 2010 JPN     0.324743    0.904306
# 2011 JPN          NaN         NaN
# 2012 JPN          NaN         NaN
# 2013 JPN          NaN         NaN
# 2014 JPN          NaN         NaN
#
# [139 rows x 40 columns]

# %%
data.query("year == " + str(row[0][0])).query("code == '" + str(row[0][1]) + "'")['gini_extra']
# Out:
# year  code
# 1972  CAN    NaN
# Name: gini_extra, dtype: float64

# %%
data.index.lexsort_depth
# Out:
# 0

# %% [markdown]
# # Compute gini from worldbank

# %%
share_dict_WB = {'D1_WB': 0.1, 'D9_WB': 0.9, 'QU1_WB': 0.2, 'QU2_WB': 0.4,
                'QU3_WB': 0.6, 'QU4_WB': 0.8, 'QU5_WB': 1}
