# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import pylab as plt
import statsmodels.api as sm
from statsmodels.sandbox.regression.predstd import wls_prediction_std

# %%
def resample(df, period):
    """Resample the frame df to period (in year)

    Input :
    -df : dataframe pandas with no index the time dimension exist as a year
        columns (column of integer)
    - period : integer : new wanted period

    Output : resampled frame
    """
    period = float(period)
    tuples = zip(df['code'],
                 (((df['year'].values) // period) * period) + period / 2.)
    df_copy = df.copy()
    df_copy.index = pd.MultiIndex.from_tuples(tuples)
    df_copy = df_copy.groupby(level=[0, 1]).mean().dropna(how='all')
    del df_copy['year']
    df_copy.index.names = ['code', 'year']
    return df_copy.sort_index()

# %%
def plot_correlations(data, min_match=20, size_tuple=(15,15)):
    """Plot the correlations between every variable of the data
    
    Input : pandas data frame with code, year as index and sorted
    in this order
    
    Output : graph of correlations
    """
    correlations = data.corr(min_periods=min_match)
    fig = plt.figure(figsize=size_tuple)
    norm = plt.cm.colors.Normalize(vmax=1, vmin=-1)
    plt.imshow(correlations, interpolation='nearest', norm=norm)
    plt.xticks(range(0, len(data.columns)), data.columns, rotation='vertical')
    plt.yticks(range(0, len(data.columns)), data.columns, rotation='horizontal')
    plt.colorbar()

# %%
variables = ["code", "year", "gini_DS", "GDP_PC_PWT", 
            "yrs_sec_schlg_M_25", "yrs_sec_schlg_F_25", "price_level_investment_PWT"]
data = pd.read_csv("../data_source/all_data.csv", usecols=variables)
data.loc[:, "log(GDP_PC_PWT)"] = data["GDP_PC_PWT"].apply(np.log)
del data["GDP_PC_PWT"]
growth = pd.read_csv("../data_source/all_data.csv", usecols=['year', 'code', 'GDP_growth_WB'])
re_growth = resample(growth, 5)
re_growth.reset_index(inplace=True)
re_growth.loc[:, "year"] -= 5
re_growth.set_index(['code', 'year'], inplace=True)
re_growth.columns = ["lagged_growth"]
re_data = resample(data, 5)
re_data = pd.merge(re_data, re_growth, how='outer', left_index=True, right_index=True)
re_data = re_data.dropna(how='any')
datafull_countries = re_data.groupby(level=0).size()[re_data.groupby(level=0).size() > 2].index.tolist()
re_data = re_data.query("code in " + str(datafull_countries))
print re_data.info()
re_data.reset_index(inplace=True)
re_data.set_index(['code', 'year'], inplace=True)
print "number of countries : ", len(set(re_data.index.levels[0]))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 244 entries, (AUS, 1967.5) to (ZMB, 1997.5)
# Data columns (total 6 columns):
# gini_DS                       244 non-null float64
# yrs_sec_schlg_F_25            244 non-null float64
# yrs_sec_schlg_M_25            244 non-null float64
# price_level_investment_PWT    244 non-null float64
# log(GDP_PC_PWT)               244 non-null float64
# lagged_growth                 244 non-null float64
# dtypes: float64(6)
# memory usage: 13.3+ KB
# None
# number of countries :  51

# %%
plot_correlations(re_data, size_tuple=(10,10))

# %% [markdown]
# Create dummy variables for country/period

# %%
for dummy in re_data.index.levels[0]:
    re_data[dummy] = (re_data.reset_index()['code'] == dummy).astype(int).values
for dummy in re_data.index.levels[1]:
    re_data[dummy] = (re_data.reset_index()['year'] == dummy).astype(int).values

# %% [markdown]
# # Regression part

# %%
X = re_data[np.delete(re_data.keys().values, 5)]
Y = re_data['lagged_growth']
X_sm = sm.add_constant(X)
model = sm.OLS(Y, X_sm)
all_results = model.fit()
print(all_results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          lagged_growth   R-squared:                       0.652
# Model:                            OLS   Adj. R-squared:                  0.530
# Method:                 Least Squares   F-statistic:                     5.343
# Date:                Tue, 01 Mar 2016   Prob (F-statistic):           5.34e-19
# Time:                        14:41:14   Log-Likelihood:                -456.03
# No. Observations:                 244   AIC:                             1040.
# Df Residuals:                     180   BIC:                             1264.
# Df Model:                          63
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------------------
# PRT                            3.1756      1.172      2.710      0.007         0.863     5.488
# SGP                            6.9216      1.048      6.606      0.000         4.854     8.989
# SWE                            4.6095      1.446      3.188      0.002         1.757     7.462
# THA                           -0.6350      1.033     -0.615      0.539        -2.673     1.403
# TTO                            1.6865      1.283      1.314      0.190        -0.845     4.218
# TUN                           -1.5555      1.029     -1.511      0.133        -3.587     0.476
# TUR                            0.4942      1.281      0.386      0.700        -2.033     3.022
# USA                            6.5780      1.905      3.453      0.001         2.819    10.337
# VEN                           -0.2899      0.975     -0.297      0.767        -2.215     1.635
# ZMB                           -8.4243      2.127     -3.962      0.000       -12.620    -4.228
# 1957.5                         4.1924      0.891      4.708      0.000         2.435     5.950
# 1962.5                         3.3188      0.686      4.836      0.000         1.965     4.673
# 1967.5                         3.4372      0.669      5.136      0.000         2.117     4.758
# 1972.5                         3.6486      0.718      5.079      0.000         2.231     5.066
# 1977.5                         3.2386      0.772      4.194      0.000         1.715     4.762
# 1982.5                         3.6131      0.807      4.476      0.000         2.020     5.206
# 1987.5                         4.0640      0.890      4.565      0.000         2.308     5.821
# 1992.5                         4.2792      0.988      4.332      0.000         2.330     6.228
# 1997.5                         4.6639      2.289      2.038      0.043         0.147     9.180
# ==============================================================================
# Omnibus:                       19.060   Durbin-Watson:                   2.452
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               58.544
# Skew:                           0.179   Prob(JB):                     1.94e-13
# Kurtosis:                       5.373   Cond. No.                          nan
# ==============================================================================
#
# Warnings:
# [1] The smallest eigenvalue is -6.56e-15. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
prstd, iv_l, iv_u = wls_prediction_std(all_results)
x = np.linspace(0, 20, len(X_sm))
fig, ax = plt.subplots(figsize=(15,8))
ax.plot(x, re_data['lagged_growth'], 'o', label="data")
ax.plot(x, all_results.fittedvalues, 'r--.', label="OLS")
#ax.plot(x, iv_u, 'r--')
#ax.plot(x, iv_l, 'r--')
ax.legend(loc='best');

# %% [markdown]
# # Normalized regressions

# %%
X_norm = X.apply(lambda x: (x - x.mean()) / x.std())
Y_norm = (Y - Y.mean()) / Y.std()
X_sm = sm.add_constant(X_norm)
model_norm = sm.OLS(Y_norm, X_sm)
norm_results = model_norm.fit()
print(norm_results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          lagged_growth   R-squared:                       0.652
# Model:                            OLS   Adj. R-squared:                  0.530
# Method:                 Least Squares   F-statistic:                     5.343
# Date:                Tue, 01 Mar 2016   Prob (F-statistic):           5.34e-19
# Time:                        09:15:11   Log-Likelihood:                -217.09
# No. Observations:                 244   AIC:                             562.2
# Df Residuals:                     180   BIC:                             786.0
# Df Model:                          63
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------------------
# const                       1.542e-15      0.044   3.51e-14      1.000        -0.087     0.087
# gini_DS                        0.3020      0.142      2.130      0.035         0.022     0.582
# yrs_sec_schlg_F_25            -0.8866      0.446     -1.987      0.048        -1.767    -0.006
# yrs_sec_schlg_M_25             1.0593      0.442      2.397      0.018         0.187     1.931
# price_level_investment_PWT    -0.0790      0.121     -0.652      0.515        -0.318     0.160
# log(GDP_PC_PWT)               -1.6720      0.253     -6.616      0.000        -2.171    -1.173
# AUS                            0.2304      0.081      2.854      0.005         0.071     0.390
# BEL                            0.1498      0.057      2.649      0.009         0.038     0.261
# BGD                           -0.4927      0.088     -5.609      0.000        -0.666    -0.319
# BGR                           -0.0818      0.061     -1.335      0.183        -0.203     0.039
# BRA                           -0.1561      0.063     -2.464      0.015        -0.281    -0.031
# CAN                            0.3670      0.089      4.132      0.000         0.192     0.542
# CHL                            0.0060      0.053      0.113      0.910        -0.098     0.110
# CHN                            0.0341      0.058      0.583      0.560        -0.081     0.150
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               58.544
# Skew:                           0.179   Prob(JB):                     1.94e-13
# Kurtosis:                       5.373   Cond. No.                          nan
# ==============================================================================
#
# Warnings:
# [1] The smallest eigenvalue is -2.36e-13. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# # Regression using only dummies

# %%
from sklearn import linear_model
clf = linear_model.Lasso(alpha=10**-50)
X_dum = re_data[np.delete(re_data.keys().values, range(6))]
clf.fit(X_dum, re_data['lagged_growth'])
print "score : ", (clf.score(X_dum, re_data['lagged_growth']))
print "Intercept : ", clf.intercept_
print "code   coeficient+intercept    average growth"
for i, variable in enumerate(X_dum.keys()):
    print variable, "   ",clf.coef_[i] + clf.intercept_, "      ", re_data.loc[variable, 'lagged_growth'].mean()
# Out:
# score :  0.544634913534
# Intercept :  3.83433506087
# code   coeficient+intercept    average growth
# AUS     3.43854784005        3.53400855394
# BEL     2.12982144442        1.96874432819
# BGD     2.77543382448        3.16454329149
# BGR     0.90409823207        0.746503918917
# BRA     3.68737407657        4.02784724569
# CAN     3.01116857285        3.70206349324
# CHL     4.72944175161        5.0279289383
# CHN     10.0583463212        9.98834095806
# COL     3.26794949116        3.29583445418
# CRI     4.28634643256        4.62681960167
# DEU     2.26747153445        2.276559579
# DNK     2.33570934738        2.17811503423
# DOM     4.54687400419        4.38927969104
# EGY     4.9123508963        5.11269731641
# ESP     3.0222244196        3.4169035026
# FIN     2.91914967799        3.09782880637
# FRA     3.07227860853        4.00395019997
# GBR     2.1617871909        2.55089665792
# GRC     2.49264594727        2.64965778391
# HKG     6.36032961485        6.35320840448
# HND     2.82441112484        3.17268133704
# IDN     5.74616762617        6.13527709319
# IND     3.91020331875        4.60109823914
# IRL     4.24712857322        4.40414040987
# IRN     1.79027885522        2.30871422821
# ITA     2.29333162873        2.28621041837
# JAM     0.487281053158        0.515166016184
# JOR     3.21052443606        3.14051907293
# JPN     3.96489351923        4.35400298625
# KOR     8.90465576642        9.3729968777
# LKA     4.67045681195        4.93980438645
# MEX     3.87272309201        4.57734997234
# MUS     5.96611182857        5.89610646543
# MYS     7.05856825976        7.07123684644
# NLD     2.79338070841        2.63578639526
# NOR     3.35046959035        3.73957905736
# NZL     2.18712269563        2.18000148526
# PAK     4.74154292196        4.9853870568
# PAN     3.05825794485        3.07092653153
# PER     2.07095435363        2.16714313147
# PHL     3.52283961737        4.53861735575
# PRT     4.19657144527        4.3170197447
# SGP     8.08014638913        8.09281497581
# SWE     2.18719066143        2.28265137533
# THA     6.40650095291        6.7613334643
# TTO     1.40858019032        2.11624449723
# TUN     4.97612969455        5.07159040845
# TUR     3.75862996749        4.33391737947
# USA     2.95221009831        3.6431050187
# VEN     1.72702355826        1.7199023479
# ZMB     2.38151470488        3.26530092273
# 1957.5     6.6377281549
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-2a33b0e1b773> in <module>()
#       7 print "code   coeficient+intercept    average growth"
#       8 for i, variable in enumerate(X_dum.keys()):
# ----> 9     print variable, "   ",clf.coef_[i] + clf.intercept_, "      ", re_data.loc[variable, 'lagged_growth'].mean()
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#    1223     def __getitem__(self, key):
#    1224         if type(key) is tuple:
# -> 1225             return self._getitem_tuple(key)
#    1226         else:
#    1227             return self._getitem_axis(key, axis=0)
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/indexing.pyc in _getitem_tuple(self, tup)
#     736     def _getitem_tuple(self, tup):
#     737         try:
# --> 738             return self._getitem_lowerdim(tup)
#     739         except IndexingError:
#     740             pass
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/indexing.pyc in _getitem_lowerdim(self, tup)
#     861         for i, key in enumerate(tup):
#     862             if is_label_like(key) or isinstance(key, tuple):
# --> 863                 section = self._getitem_axis(key, axis=i)
#     864
#     865                 # we have yielded a scalar ?
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/indexing.pyc in _getitem_axis(self, key, axis)
#    1369
#    1370         # fall thru to straight lookup
# -> 1371         self._has_valid_type(key, axis)
#    1372         return self._get_label(key, axis=axis)
#    1373
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/indexing.pyc in _has_valid_type(self, key, axis)
#    1321
#    1322             try:
# -> 1323                 key = self._convert_scalar_indexer(key, axis)
#    1324                 if not key in ax:
#    1325                     error()
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/indexing.pyc in _convert_scalar_indexer(self, key, axis)
#     167         ax = self.obj._get_axis(min(axis, self.ndim - 1))
#     168         # a scalar
# --> 169         return ax._convert_scalar_indexer(key, kind=self.name)
#     170
#     171     def _convert_slice_indexer(self, key, axis):
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/index.pyc in _convert_scalar_indexer(self, key, kind)
#     874             warnings.warn("scalar indexers for index type {0} should be integers and not floating point".format(
#     875                 type(self).__name__), FutureWarning, stacklevel=3)
# --> 876             return to_int()
#     877
#     878         return key
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/index.pyc in to_int()
#     856             ikey = int(key)
#     857             if ikey != key:
# --> 858                 return self._invalid_indexer('label', key)
#     859             return ikey
#     860
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/index.pyc in _invalid_indexer(self, form, key)
#    1015                                                            klass=type(self),
#    1016                                                            key=key,
# -> 1017                                                            kind=type(key)))
#    1018
#    1019     def get_duplicates(self):
#
# TypeError: cannot do label indexing on <class 'pandas.core.index.MultiIndex'> with these indexers [1957.5] of <type 'numpy.float64'>

# %%
x = np.linspace(0, 20, len(X_dum))
fig, ax = plt.subplots(figsize=(15,8))
ax.plot(x, re_data['lagged_growth'], 'o', label="data")
ax.plot(x, clf.predict(X_dum), 'r--.', label="OLS")
#ax.plot(x, iv_u, 'r--')
#ax.plot(x, iv_l, 'r--')
ax.legend(loc='best');

# %% [markdown]
# # Now we fit the residus on the other variables

# %%
residus = re_data['lagged_growth'] - clf.predict(X_dum)
print "Growth standard deviation : ", re_data['lagged_growth'].std()
print "Residus standard deviation : ", residus.std()
# Out:
# Growth standard deviation :  2.66251506445
# Residus standard deviation :  1.79668498523

# %%
from sklearn import linear_model
X_var = re_data[np.delete(re_data.keys().values, range(5, len(re_data.keys())))]
clf_res = linear_model.Lasso(alpha=10**-50)
clf_res.fit(X_var, residus)
print "score : ", (clf_res.score(X_var, re_data['lagged_growth']))
print "Intercept : ", clf_res.intercept_
print "variable   coeficient"
for i, variable in enumerate(X_var.keys()):
    print variable, "   ",clf_res.coef_[i]
print "Residus standard deviation : ", residus.std()
print "Residus of residus standard deviation : ", (residus - clf_res.predict(X_var)).std()
# Out:
# score :  -2.28546674149
# Intercept :  1.87454117344
# variable   coeficient
# gini_DS     0.693591201319
# yrs_sec_schlg_F_25     -0.0939998374655
# yrs_sec_schlg_M_25     0.317295245701
# price_level_investment_PWT     -0.00383996123312
# log(GDP_PC_PWT)     -0.262804159999
# Residus standard deviation :  1.79668498523
# Residus of residus standard deviation :  1.78128289026

# %%
x = np.linspace(0, 20, len(X_var))
fig, ax = plt.subplots(figsize=(15,8))
ax.plot(x, residus, 'o', label="data")
ax.plot(x, clf_res.predict(X_var), 'r--.', label="OLS")
#ax.plot(x, iv_u, 'r--')
#ax.plot(x, iv_l, 'r--')
ax.legend(loc='best');

# %% [markdown]
# # Scatter plots

# %%
f, axarr = plt.subplots(2, 3, figsize=(20,12))
for n, var in enumerate(X_var.keys()):
    i,j = n/3, n%3
    axarr[i, j].plot(X_var[var], Y, 'o')
    axarr[i, j].set_title(var)
